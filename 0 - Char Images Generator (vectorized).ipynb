# %%
# -*- coding: utf-8 -*- 

#------------------------------------ Imports ----------------------------------#

# Import python imaging libs
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageFilter

# Import noise creating library
from noisify.recipes import human_error, machine_error

# Import operating system lib and time
import os
import time

# Import random generator
from random import randint
import numpy as np

# import csv reader and pandas
import csv
import pandas as pd

# %%
#------------------------------------ Cleanup ----------------------------------#	
def Cleanup():
    print("Cleaning up...", end="")
    # Delete ds_store file
    if os.path.isfile(font_dir + '.DS_Store'):
        os.unlink(font_dir + '.DS_Store')
	
    # Delete all files from output directory
    for file in os.listdir(out_dir):
        file_path = os.path.join(out_dir, file)
        if os.path.isfile(file_path):
            os.unlink(file_path)
    
    print("done.")
    return

# %%
#---------------------------------- Input and Output ---------------------------#

# Directory containing fonts
font_dir = './fonts/font_files/'

# Output
out_dir = './train_data/chars/'

# %%
def duration_text(secs):

    secs = round(secs, 2)
    mins = int(secs // 60)
    hours = int(mins // 60)
    
    remain_mins = int(mins - hours * 60)
    remain_secs = round(secs - mins * 60, 2)
    
    remain_secs_text = "0" + str(remain_secs) if len(str(int(remain_secs))) == 1 else str(remain_secs)
    remain_mins_text = "0" + str(remain_mins) if len(str(remain_mins)) == 1 else str(remain_mins)
    
    time_str = remain_secs_text + "s"
    if hours > 0:
        hours_text = "0" + str(hours) if len(str(hours)) == 1 else str(hours)
        time_str = hours_text + ":" + remain_mins_text + ":" + time_str
    elif mins > 0:
        time_str = remain_mins_text + ":" + time_str
    else:
        time_str = str(remain_secs) + "s"
        
    return time_str

# %%
dataset = []
with open('chars.csv', newline='', encoding='utf-8') as csvfile:
    data = csv.reader(csvfile, delimiter=',', quotechar='"')
    for row in data:
        dataset.append(row)

chars_df = pd.DataFrame(dataset[1:], columns=['index', 'char', 'name'])
chars_df = chars_df.set_index(chars_df.columns[0])

# %%
#------------------------------ Generate Characters ----------------------------#
def GenerateCharacters():
    # Counter
    k = 1
    
    durations = []
    
    X_dataset = []
    y_dataset = []
    
    # Process the font files
    for dirname, dirnames, filenames in os.walk(font_dir):
        size = len(filenames)
        item = 1
        # For each font do
        for filename in filenames:
            print(item, "/", size, ":", filename, "... ", end="")
            start_time = time.time()
            # Get font full file path
            font_resource_file = os.path.join(dirname, filename)
            
            # For each character do
            for index, row in chars_df.iterrows():
                # For each font size do
                for font_size in font_sizes:
                    if font_size > 0:
                        # For each background color do
                        for background_color in background_colors:
                            # For each rotation option do
                            for rotation in rotations:
                                # For each type of quality do
                                for quality in qualities:
                                    # Create row dictionary
                                    file_row = dict()

                                    # Set char id
                                    file_row['index'] = index
                                    file_row['char'] = row['char']
                                    file_row['char_name'] = row['name']
                                    file_row['font_file'] = filename
                                    file_row['font_size'] = font_size
                                    file_row['rotation'] = rotation
                                    file_row['quality'] = quality
                                    file_row['background_color'] = background_color

                                    # Convert the character into unicode
                                    character = row['char']

                                    # Create character image : 
                                    # Grayscale, image size, background color
                                    char_image = Image.new('RGB', (image_size, image_size),\
                                    background_color)

                                    # Draw character image
                                    draw = ImageDraw.Draw(char_image)

                                    # Specify font : Resource file, font size
                                    font = ImageFont.truetype(font_resource_file, font_size, encoding='unic')

                                    # Get character width and height
                                    (font_width, font_height) = font.getsize(character)

                                    # Calculate x position
                                    x = (image_size - font_width)/2

                                    # Calculate y position
                                    y = (image_size - font_height)/2

                                    # Draw text : Position, String, 
                                    # Options = Fill color, Font
                                    draw.text((x, y), character, (245-background_color) + \
                                    randint(0, 10) , font=font)

                                    # Set Character Rotation
                                    char_image = char_image.rotate(angle=rotation, fillcolor=background_color)

                                    # If quality is set to noisy, add noise to the image
                                    if quality == "noisy":
                                        combined_noise = machine_error(errors[0]) + human_error(errors[1])
                                        char_image = list(combined_noise(char_image))[0]

                                    # Final file name    				
                                    file_name = out_dir + str(k) + '_' + \
                                    filename + '_fs_' + \
                                    str(font_size) + '_bc_' + \
                                    str(background_color) + '_rot_' + \
                                    str(rotation) + '_' + \
                                    str(quality) + '.' + \
                                    row['name'] + '.png'

                                    file_row['file_name'] = file_name
                                    
                                    char_data = np.asarray(char_image)
                                    X_dataset.append(char_data)
                                    y_dataset.append([index])

                                    # Increment counter
                                    k = k + 1

            end_time = time.time()
            duration = end_time - start_time
            durations.append(duration)
            avg_duration = sum(durations) / len(durations)
            eta = (size - item) * avg_duration
            eta_text = duration_text(eta)
            print(round(duration,2), " s. ETA: ", eta_text, ".", sep="")
            
            item += 1
            
    return X_dataset, y_dataset

# %%
#------------------------------------- Colors ----------------------------------#

# Background color
white_colors = (215, 225, 235, 245)
black_colors = (0, 10, 20, 30)
gray_colors = (135, 145, 155)

background_colors = white_colors + black_colors + gray_colors

#-------------------------------------- Sizes ----------------------------------#

# Character sizes
font_sizes = (18, 24)
    	
# Image size
image_size = 32

#-------------------------------------- Augmentation Params --------------------#

# Blur factor
blur = 1

# Writing error generation
qualities = ["clean", "noisy"]
errors = (20, 45) # 20 machine error; # 45 human error

# Rotations
rotations = (-45, -5, 0, 5, 45)

# %%
#-------------------------------------- Main -----------------------------------#

# Do cleanup
# Cleanup()

# Generate characters
X_dataset, y_dataset = GenerateCharacters()
# Out:
# 1 / 85 : AbrilFatface-Regular.otf ... 25.29 s. ETA: 35:24.11s.
# 2 / 85 : Aileron-Bold.otf ... 24.85 s. ETA: 34:40.68s.
# 3 / 85 : Aileron-Italic.otf ... 24.37 s. ETA: 33:56.53s.
# 4 / 85 : Aileron-Light.otf ... 24.53 s. ETA: 33:25.41s.
# 5 / 85 : Aileron-Regular.otf ... 24.46 s. ETA: 32:55.85s.
# 6 / 85 : Aller_Bd.ttf ... 44.44 s. ETA: 36:51.12s.
# 7 / 85 : Aller_It.ttf ... 43.39 s. ETA: 39:14.72s.
# 8 / 85 : Aller_Rg.ttf ... 42.76 s. ETA: 40:45.55s.
# 9 / 85 : Andada-Bold.otf ... 26.8 s. ETA: 39:31.95s.
# 10 / 85 : Andada-Italic.otf ... 26.45 s. ETA: 38:25.07s.
# 11 / 85 : Andada-Regular.otf ... 26.63 s. ETA: 37:26.7s.
# 12 / 85 : ArchivoBlack.otf ... 25.84 s. ETA: 36:28.85s.
# 13 / 85 : arial-ro.ttf ... 24.59 s. ETA: 35:29.01s.
# 14 / 85 : ArialUnicodeMS.ttf ... 37.26 s. ETA: 35:38.46s.
# 15 / 85 : Baloo-Regular.ttf ... 36.94 s. ETA: 35:40.17s.
# 16 / 85 : Bitter-Bold.otf ... 31.27 s. ETA: 35:12.6s.
# 17 / 85 : Bitter-Italic.otf ... 26.44 s. ETA: 34:25.29s.
# 18 / 85 : Bitter-Regular.otf ... 27.35 s. ETA: 33:43.66s.
# 19 / 85 : Blogger_Sans-Bold.otf ... 28.6 s. ETA: 33:07.9s.
# 20 / 85 : Blogger_Sans-Italic.otf ... 28.15 s. ETA: 32:31.39s.
# 21 / 85 : Blogger_Sans-Light.otf ... 28.45 s. ETA: 31:56.58s.
# 22 / 85 : Blogger_Sans.otf ... 28.67 s. ETA: 31:22.97s.
# 23 / 85 : BreeSerif-Regular.otf ... 28.38 s. ETA: 30:49.02s.
# 24 / 85 : Changa-Bold.ttf ... 31.07 s. ETA: 30:22.37s.
# 25 / 85 : Changa-Light.ttf ... 38.24 s. ETA: 30:12.59s.
# 26 / 85 : Changa-Regular.ttf ... 41.57 s. ETA: 30:08.16s.
# 27 / 85 : cmunbmr.ttf ... 33.39 s. ETA: 29:43.4s.
# 28 / 85 : cmunrm.ttf ... 28.12 s. ETA: 29:07.3s.
# 29 / 85 : Courier Prime Sans Bold.ttf ... 30.59 s. ETA: 28:36.52s.
# 30 / 85 : Courier Prime Sans Italic.ttf ... 31.47 s. ETA: 28:07.36s.
# 31 / 85 : Courier Prime Sans.ttf ... 30.79 s. ETA: 27:36.88s.
# 32 / 85 : CroissantOne-Regular.ttf ... 25.75 s. ETA: 26:58.02s.
# 33 / 85 : Familiar_Pro-Bold.otf ... 28.42 s. ETA: 26:24.18s.
# 34 / 85 : finenessprobolditalic.otf ... 28.72 s. ETA: 25:51.1s.
# 35 / 85 : finenessprolight.otf ... 28.2 s. ETA: 25:17.53s.
# 36 / 85 : finenessproregular.otf ... 26.43 s. ETA: 24:41.84s.
# 37 / 85 : FoglihtenNo07.otf ... 28.06 s. ETA: 24:08.76s.
# 38 / 85 : Geometry_Soft_Pro-Bold_N.otf ... 27.25 s. ETA: 23:34.95s.
# 39 / 85 : JockeyOne-Regular.otf ... 28.65 s. ETA: 23:03.12s.
# 40 / 85 : Judson-Bold.otf ... 29.41 s. ETA: 22:32.31s.
# 41 / 85 : Judson-Italic.otf ... 29.16 s. ETA: 22:01.3s.
# 42 / 85 : Judson-Regular.otf ... 29.84 s. ETA: 21:31.08s.
# 43 / 85 : Kalam-Bold.ttf ... 30.79 s. ETA: 21:01.8s.
# 44 / 85 : Kalam-Light.ttf ... 31.3 s. ETA: 20:32.94s.
# 45 / 85 : Kalam-Regular.ttf ... 31.52 s. ETA: 20:04.15s.
# 46 / 85 : konstytucyja_091.otf ... 30.57 s. ETA: 19:34.44s.
# 47 / 85 : LibreBaskerville-Bold.otf ... 30.25 s. ETA: 19:04.44s.
# 48 / 85 : LibreBaskerville-Italic.otf ... 30.74 s. ETA: 18:34.8s.
# 49 / 85 : LibreBaskerville-Regular.otf ... 30.69 s. ETA: 18:05.08s.
# 50 / 85 : LifeSavers-Regular.ttf ... 34.03 s. ETA: 17:37.66s.
# 51 / 85 : Merriweather-Bold.otf ... 31.13 s. ETA: 17:08.05s.
# 52 / 85 : Merriweather-Italic.otf ... 31.27 s. ETA: 16:38.47s.
# 53 / 85 : Merriweather-Light.otf ... 30.9 s. ETA: 16:08.6s.
# 54 / 85 : Merriweather-Regular.otf ... 30.66 s. ETA: 15:38.56s.
# 55 / 85 : MerriweatherSans-Bold.otf ... 29.13 s. ETA: 15:07.66s.
# 56 / 85 : MerriweatherSans-Italic.otf ... 28.29 s. ETA: 14:36.39s.
# 57 / 85 : MerriweatherSans-Light.otf ... 29.44 s. ETA: 14:05.79s.
# 58 / 85 : MerriweatherSans-Regular.otf ... 27.7 s. ETA: 13:34.41s.
# 59 / 85 : NewsCycle-Bold.ttf ... 29.1 s. ETA: 13:03.78s.
# 60 / 85 : NewsCycle-Regular.ttf ... 28.38 s. ETA: 12:32.9s.
# 61 / 85 : NewtSerif-Italic.otf ... 28.3 s. ETA: 12:02.07s.
# 62 / 85 : NewtSerif.otf ... 27.68 s. ETA: 11:31.09s.
# 63 / 85 : NewtSerifBold.otf ... 28.55 s. ETA: 11:00.52s.
# 64 / 85 : NewtSerifLight.otf ... 27.7 s. ETA: 10:29.73s.
# 65 / 85 : new_athena_unicode.ttf ... 26.88 s. ETA: 09:58.79s.
# 66 / 85 : OldStandard-Bold.ttf ... 27.61 s. ETA: 09:28.18s.
# 67 / 85 : OldStandard-Italic.ttf ... 27.85 s. ETA: 08:57.72s.
# 68 / 85 : OldStandard-Regular.ttf ... 27.81 s. ETA: 08:27.33s.
# 69 / 85 : OpenSans-Bold.ttf ... 33.18 s. ETA: 07:58.26s.
# 70 / 85 : OpenSans-Italic.ttf ... 40.54 s. ETA: 07:30.65s.
# 71 / 85 : OpenSans-Light.ttf ... 48.71 s. ETA: 07:04.29s.
# 72 / 85 : OpenSans-Regular.ttf ... 58.07 s. ETA: 06:39.0s.
# 73 / 85 : Play-Bold.ttf ... 42.24 s. ETA: 06:10.2s.
# 74 / 85 : Play-Regular.ttf ... 41.0 s. ETA: 05:40.86s.
# 75 / 85 : PoetsenOne-Regular.otf ... 46.64 s. ETA: 05:11.96s.
# 76 / 85 : Sansita-Bold.otf ... 46.86 s. ETA: 04:42.62s.
# 77 / 85 : Sansita-Italic.otf ... 48.04 s. ETA: 04:12.95s.
# 78 / 85 : Sansita-Light.otf ... 46.33 s. ETA: 03:42.65s.
# 79 / 85 : Sansita-Regular.otf ... 46.68 s. ETA: 03:11.97s.
# 80 / 85 : spinwerad.ttf ... 78.02 s. ETA: 02:42.85s.
# 81 / 85 : WorkSans-Bold.otf ... 44.68 s. ETA: 02:10.88s.
# 82 / 85 : WorkSans-Italic.otf ... 44.29 s. ETA: 01:38.58s.
# 83 / 85 : WorkSans-Light.otf ... 45.14 s. ETA: 01:06.02s.
# 84 / 85 : WorkSans-Regular.otf ... 44.76 s. ETA: 33.15s.
# 85 / 85 : Znikomit.otf ... 78.74 s. ETA: 0.0s.

# %%
# save to npy file
data = [X_dataset, y_dataset]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-06812e79320c> in <module>
#       1 # save to npy file
#       2 data = [X_dataset, y_dataset]
# ----> 3 np.save('full_char_dataset.npy', data)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     550     try:
#     551         arr = np.asanyarray(arr)
# --> 552         format.write_array(fid, arr, allow_pickle=allow_pickle,
#     553                            pickle_kwargs=pickle_kwargs)
#     554     finally:
#
# ~\anaconda3\lib\site-packages\numpy\lib\format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     674         if pickle_kwargs is None:
#     675             pickle_kwargs = {}
# --> 676         pickle.dump(array, fp, protocol=3, **pickle_kwargs)
#     677     elif array.flags.f_contiguous and not array.flags.c_contiguous:
#     678         if isfileobj(fp):
#
# MemoryError:

# %%
np.save('full_char_dataset.npy', data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-81aa048e1c26> in <module>
# ----> 1 np.save('full_char_dataset.npy', data)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     550     try:
#     551         arr = np.asanyarray(arr)
# --> 552         format.write_array(fid, arr, allow_pickle=allow_pickle,
#     553                            pickle_kwargs=pickle_kwargs)
#     554     finally:
#
# ~\anaconda3\lib\site-packages\numpy\lib\format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     674         if pickle_kwargs is None:
#     675             pickle_kwargs = {}
# --> 676         pickle.dump(array, fp, protocol=3, **pickle_kwargs)
#     677     elif array.flags.f_contiguous and not array.flags.c_contiguous:
#     678         if isfileobj(fp):
#
# MemoryError:

# %%
output_df = pd.DataFrame(files_data)

# %%
output_df
# Out:
#         index char       char_name                 font_file  font_size  \
# 0           0    0               0  AbrilFatface-Regular.otf         18
# 1           0    0               0  AbrilFatface-Regular.otf         18
# 2           0    0               0  AbrilFatface-Regular.otf         18
# 3           0    0               0  AbrilFatface-Regular.otf         18
# 4           0    0               0  AbrilFatface-Regular.otf         18
# ...       ...  ...             ...                       ...        ...
# 1832595    97    _  sym_underscore              Znikomit.otf         24
# 1832596    97    _  sym_underscore              Znikomit.otf         24
# 1832597    97    _  sym_underscore              Znikomit.otf         24
# 1832598    97    _  sym_underscore              Znikomit.otf         24
# 1832599    97    _  sym_underscore              Znikomit.otf         24
#
#          rotation quality  background_color  \
# 0             -45   clean               215
# 1             -45   noisy               215
# 2              -5   clean               215
# 3              -5   noisy               215
# 4               0   clean               215
# ...           ...     ...               ...
# 1832595         0   noisy               155
# 1832596         5   clean               155
# 1832597         5   noisy               155
# 1832598        45   clean               155
# 1832599        45   noisy               155
#
#                                                  file_name
# 0        ./chars/1_AbrilFatface-Regular.otf_fs_18_bc_21...
# 1        ./chars/2_AbrilFatface-Regular.otf_fs_18_bc_21...
# 2        ./chars/3_AbrilFatface-Regular.otf_fs_18_bc_21...
# 3        ./chars/4_AbrilFatface-Regular.otf_fs_18_bc_21...
# 4        ./chars/5_AbrilFatface-Regular.otf_fs_18_bc_21...
# ...                                                    ...
# 1832595  ./chars/1832596_Znikomit.otf_fs_24_bc_155_rot_...
# 1832596  ./chars/1832597_Znikomit.otf_fs_24_bc_155_rot_...
# 1832597  ./chars/1832598_Znikomit.otf_fs_24_bc_155_rot_...
# 1832598  ./chars/1832599_Znikomit.otf_fs_24_bc_155_rot_...
# 1832599  ./chars/1832600_Znikomit.otf_fs_24_bc_155_rot_...
#
# [1832600 rows x 9 columns]

# %%
output_df.to_csv('final_files_mapping.csv', index=False)
